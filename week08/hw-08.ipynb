# %% [markdown]
# # Week8 Homework
# ## Working with Strings
#
# The data frame contains notes taken by staff members. Your task is to clean it up to make it usable for analysis.
#
# ### Tasks
# * Create start date, end date columns and populate the values (If notes don't include month or day use 1 for missing value)
#
# i.e:
#
#     - 2018 => 2018-01-01
#     - June 2021 => 2021-06-01
#     - 2020 => 2020-01-01
#
# * Create phone number column (If notes don't include phone numbers, use None)
# * Create a column `duration` showing difference between start & end dates in years as a whole number
#
# Note: Choose one of the following datasets to work on based on your taste!

# %%
import pandas as pd
from datetime import datetime
import re
import numpy as np

# %%
spicy = 'https://raw.githubusercontent.com/msaricaumbc/DS_Data/master/strings/hw_data_spicy.csv'
less_spicy = 'https://raw.githubusercontent.com/msaricaumbc/DS_Data/master/strings/hw_data_less_spicy.csv'

# %%
df = pd.read_csv(less_spicy, index_col=0)

# %%
df['notes']
# Out:
# 0                          start July 1970/end 2013-06-17
# 1                            start 1971-02 end 04/10/2012
# 2       start January 1977 end 12/20/2018 pn: 001-464-...
# 3                         start 1986-02 end February 2010
# 4                               start 1975/end 07/27/2018
#                               ...
# 1995                      start 05/04/1988-end 08/19/2018
# 1996             start 1978-08-end 2017-06-p#  1886569390
# 1997                      start 05/06/1984/end 08/11/2021
# 1998     start 2004-02-22 end 2018 p/n  709.702.0599x5879
# 1999                      start 1977-01-31 end 05/18/2020
# Name: notes, Length: 2000, dtype: object

# %%
df['start_date'] = df['notes'].str.extract(r'\bstart(.+?)end\b', expand=False).str.rstrip("/").str.rstrip("-").str.strip()

# %%
df['end_date'] = df.notes.apply(lambda x: re.findall(r"\bend.+pn\b|\bend.+P\b|\bend.+p\/|\bend.+#|\bend.+\b", x)[0].strip("end").lower().rstrip("/p").rstrip("p").strip("-p#").strip("-p/").strip())

# %%
def getPhoneNum(x):
    match=re.search(r"\d{0,3}?\W\d\d\d\W\d\d\d\W\d\d\d\d([x]?\d{3,5})?|\d{10,}", x)
    return match.group() if match else None


def parsing_date(text):
    for fmt in ('%Y-%m-%d', '%d.%m.%Y', '%d/%m/%Y', '%B %Y', '%Y', '%Y-%m', '%m/%d/%Y'):
        try:
            d = datetime.strptime(text, fmt)
            return d.strftime('%Y-%m-%d')
        except ValueError:
            pass
    raise ValueError('no valid date format found', text)

# %%
df['phone_num']=df.notes.apply(lambda x: getPhoneNum(x))

# %%
df['start_date']=df.start_date.apply(parsing_date)
df['start_date']=pd.to_datetime(df['start_date'], format='%Y-%m-%d', errors = 'coerce')

# %%
df['end_date']=df.end_date.apply(parsing_date)
df['end_date']=pd.to_datetime(df['end_date'], format='%Y-%m-%d', errors = 'coerce')

# %%
df['duration']=(df['end_date']-df['start_date'])/np.timedelta64(1, 'Y')
df['duration']=df['duration'].apply(np.floor)
df.head(20)
# Out:
#                                   email  \
# 0                margaret41@santos.info
# 1                   donna16@jimenez.com
# 2       edwardslinda@cabrera-murphy.org
# 3           gutierrezdenise@hotmail.com
# 4                     jherrera@koch.com
# 5            meganmcdonald@wallace.info
# 6        martinkellie@thomas-cannon.net
# 7            elizabethmoore@hotmail.com
# 8                  rosemarcus@yahoo.com
# 9               jessicacosta@henson.com
# 10                    luke71@burton.net
# 11              tbaker@duncan-ortiz.com
# 12                   morgan26@gmail.com
# 13           melissacrawford@brown.info
# 14                    dgarcia@gmail.com
# 15  rosalestiffany@lewis-hutchinson.com
# 16                     ksmith@yahoo.com
# 17           christopherbowen@gmail.com
# 18            paulstone@frey-miller.com
# 19              jillgutierrez@gmail.com
#
#                                                 notes start_date   end_date  \
# 0                      start July 1970/end 2013-06-17 1970-07-01 2013-06-17
# 1                        start 1971-02 end 04/10/2012 1971-02-01 2012-10-04
# 2   start January 1977 end 12/20/2018 pn: 001-464-... 1977-01-01 2018-12-20
# 3                     start 1986-02 end February 2010 1986-02-01 2010-02-01
# 4                           start 1975/end 07/27/2018 1975-01-01 2018-07-27
# 5                     start January 1996/end May 2017 1996-01-01 2017-05-01
# 6                     start 2002-08-03-end 09/11/2016 2002-08-03 2016-11-09
# 7                              start 1978/end 2020-09 1978-01-01 2020-09-01
# 8   start 2008-11-30/end 2011-12/P# 001-467-263-22... 2008-11-30 2011-12-01
# 9   start 2003-11 end February 2018 P# +1-946-742-... 2003-11-01 2018-02-01
# 10     start 1980-04-end 2010-08-pn: 736.011.4403x188 1980-04-01 2010-08-01
# 11  start December 1972-end 2021-p/n  001-689-196-... 1972-12-01 2021-01-01
# 12  start 1993-03-16-end 2020-04-p#  884-899-3487x... 1993-03-16 2020-04-01
# 13                          start 1995/end 03/13/2016 1995-01-01 2016-03-13
# 14                          start 2009-03 end 2018-05 2009-03-01 2018-05-01
# 15                  start December 2002 end July 2021 2002-12-01 2021-07-01
# 16                                start 1982/end 2017 1982-01-01 2017-01-01
# 17                                start 2006/end 2020 2006-01-01 2020-01-01
# 18                     start 2004-11-28/end June 2016 2004-11-28 2016-06-01
# 19      start 1979-10/end 11/25/2019/P# (208)502-7177 1979-10-01 2019-11-25
#
#                  phone_num  duration
# 0                     None      42.0
# 1                     None      41.0
# 2         001-464-616-8819      41.0
# 3                     None      24.0
# 4                     None      43.0
# 5                     None      21.0
# 6                     None      14.0
# 7                     None      42.0
# 8   001-467-263-2241x61560       3.0
# 9       1-946-742-6723x151      14.0
# 10        736.011.4403x188      30.0
# 11  001-689-196-2871x45531      48.0
# 12      884-899-3487x89277      27.0
# 13                    None      21.0
# 14                    None       9.0
# 15                    None      18.0
# 16                    None      35.0
# 17                    None      13.0
# 18                    None      11.0
# 19           (208)502-7177      40.0

# %% [markdown]
# <h5>Reference</h5>
# https://stackoverflow.com/questions/23581128/how-to-format-date-string-via-multiple-formats-in-python
# <br>
# https://stackoverflow.com/questions/42980662/convert-string-with-month-name-to-datetime
